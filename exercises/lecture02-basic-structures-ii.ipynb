# %% [markdown]
# # Lecture 02 Exercise: Basic Structures II
#
# Practice dictionaries and JSON.

# %%
import json

hotel = {
    "name": "Example Hotel",
    "city": "Vienna",
    "price": 120,
    "stars": 4,
}

# TODO: add a new key named "good_deal" with a boolean value.

# %% [markdown]
# Convert the dictionary to a JSON string with indentation. Then convert it back to a dictionary and inspect the result.

# %%
# TODO: use json.dumps(...) and json.loads(...).
